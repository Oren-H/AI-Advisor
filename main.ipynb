# %%
import csv
import pandas as pd

# %%
# read the csv file
# make pd out of all the csv files in this director

df = pd.read_csv('test_results_invalid_20250710_210506.csv')
df.head()
# Out:
#    course_code                                       course_title  department  \
# 0          NaN         COMS E3899 Research Training. 0.00 points.         NaN
# 1          NaN                     COMS E3999 Fieldwork. 1 point.         NaN
# 2          NaN  COMS E4115 PROGRAMMING LANG ＆ TRANSL. 3.00 poi...         NaN
# 3          NaN   COMS E4773 Machine Learning Theory. 3.00 points.         NaN
# 4          NaN             COMS E4775 Causal Inference. 3 points.         NaN
#
#    section  times  location  instructor  credits  enrollment  \
# 0      NaN    NaN       NaN         NaN      0.0         NaN
# 1      NaN    NaN       NaN         NaN      1.0         NaN
# 2      NaN    NaN       NaN         NaN      3.0         NaN
# 3      NaN    NaN       NaN         NaN      3.0         NaN
# 4      NaN    NaN       NaN         NaN      3.0         NaN
#
#                                          description  \
# 0  Research training course. Recommended in prepa...
# ...

# %%
df_2 = pd.read_csv('test_results_valid_20250710_210506.csv')
df_2.head()
# Out:
#   course_code                                    course_title department  \
# 0  COMS W3998   UNDERGRAD PROJECTS IN COMPUTER SCIENCE. 1.00-       COMS
# 1  COMS W3998   UNDERGRAD PROJECTS IN COMPUTER SCIENCE. 1.00-       COMS
# 2   COMS 1001  Introduction to Information Science. 3 points.       COMS
# 3   COMS 1002                           COMPUTING IN CONTEXT.       COMS
# 4   COMS 1002                           COMPUTING IN CONTEXT.       COMS
#
#      section                   times  location                     instructor  \
# 0        NaN                     NaN       NaN                            NaN
# 1        NaN                     NaN       NaN                            NaN
# 2  001/12789  T Th 10:10am - 11:25am  Room TBA                    Adam Cannon
# 3  001/12790    T Th 1:10pm - 2:25pm  Room TBA  Adam Cannon, Mark Santolucito
# 4  002/12791    T Th 1:10pm - 2:25pm  Room TBA               Mark Santolucito
#
# ...

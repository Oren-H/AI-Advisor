# %%
import csv
import pandas as pd

# %%
# read the csv file
# make pd out of all the csv files in this director

df = pd.read_csv('/Users/alt2005/ai_advisor/AI-Advisor/columbia_courses_invalid.csv')
df.head()
# Out:
#    course_code                                       course_title  department  \
# 0          NaN  AFAS UN1003 Blackness and Frenchness: A Radica...         NaN
# 1          NaN   AFAS UN3030 AFRICAN-AMERICAN MUSIC. 3.00 points.         NaN
# 2          NaN  AFAS UN3936 Black Intellectuals Seminar. 4 poi...         NaN
# 3          NaN  AFAS GU4031 POPULAR MUSIC/PROTEST MOVEMNTS. 4....         NaN
# 4          NaN  AFAS GU4035 Criminal Justice and the Carceral ...         NaN
#
#    section  times  location  instructor  credits  enrollment  \
# 0      NaN    NaN       NaN         NaN      4.0         NaN
# 1      NaN    NaN       NaN         NaN      3.0         NaN
# 2      NaN    NaN       NaN         NaN      4.0         NaN
# 3      NaN    NaN       NaN         NaN      4.0         NaN
# 4      NaN    NaN       NaN         NaN      4.0         NaN
#
#                                          description  \
# 0                                                NaN
# ...

# %%
df_2 = pd.read_csv('/Users/alt2005/ai_advisor/AI-Advisor/columbia_courses.csv')
df_2.head(20)
# Out:
#    course_code                                       course_title department  \
# 0    AFAS 1001                     INTRO TO AFRICAN-AMER STUDIES.       AFAS
# 1    AFAS 1002         Major Debates in African-American Studies.       AFAS
# 2    AFAS 3943                                Senior Pro Seminar.       AFAS
# 3    AFAS 3930                    TOPICS IN THE BLACK EXPERIENCE.       AFAS
# 4    AFAS 3940                             SENIOR THESIS SEMINAR.       AFAS
# 5    AFAS 4080  Black Feminist Imaginaries: Practices and Poet...       AFAS
# 6    AFAS 4080  Black Feminist Imaginaries: Practices and Poet...       AFAS
# 7    AFAS 4080  Black Feminist Imaginaries: Practices and Poet...       AFAS
# 8    AFAS 4080  Black Feminist Imaginaries: Practices and Poet...       AFAS
# 9    AFAS 4080  Black Feminist Imaginaries: Practices and Poet...       AFAS
# 10   AFAS 4080  Black Feminist Imaginaries: Practices and Poet...       AFAS
# ...
